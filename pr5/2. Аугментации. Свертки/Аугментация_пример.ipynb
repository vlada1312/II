# %% [markdown]
# # Пример аугментации данных для классификации изображений.

# %% [markdown]
# # Классификация кошек и собак с аугментацией данных
#
# Давайте посмотрим, как аугментация влияет на работу моделей, попробуем различить кошек и собак с и без аугментации.

# %%
import tensorflow as tf # для работы с нейронными сетями
from tensorflow.keras.preprocessing.image import ImageDataGenerator # генератор данных
import os # для работы с файловой системой
import numpy as np #
import matplotlib.pyplot as plt #

# %% [markdown]
# ## Загрузка данных

# %% [markdown]
# Будем работать с набором данных, содержащим изображения [кошек и собак](https://www.kaggle.com/c/dogs-vs-cats/data). Загрузим
# его с URL, распакуем.

# %%
_URL = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip'

zip_dir = tf.keras.utils.get_file('cats_and_dogs_filterted.zip', origin=_URL, extract=True)
# Out:
# Downloading data from https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# 68606236/68606236 [==============================] - 3s 0us/step

# %% [markdown]
# Набор данных имеет следующую структуру на диске:.
#
# <pre style="font-size: 10.0pt; font-family: Arial; line-height: 2; letter-spacing: 1.0pt;" >
# <b>cats_and_dogs_filtered</b>
# |__ <b>train</b>
#     |______ <b>cats</b>: [cat.0.jpg, cat.1.jpg, cat.2.jpg ....]
#     |______ <b>dogs</b>: [dog.0.jpg, dog.1.jpg, dog.2.jpg ...]
# |__ <b>validation</b>
#     |______ <b>cats</b>: [cat.2000.jpg, cat.2001.jpg, cat.2002.jpg ....]
#     |______ <b>dogs</b>: [dog.2000.jpg, dog.2001.jpg, dog.2002.jpg ...]
# </pre>

# %% [markdown]
# Пропишем пути к файлам.

# %%
base_dir = os.path.join(os.path.dirname(zip_dir), 'cats_and_dogs_filtered') # директория с данными
train_dir = os.path.join(base_dir, 'train') # директория файлов для обучения
validation_dir = os.path.join(base_dir, 'validation') # дирекотрия файлов для проверки

# %%
train_cats_dir = os.path.join(train_dir, 'cats')  # директория файлов для обучения с кошками
train_dogs_dir = os.path.join(train_dir, 'dogs')  # директория файлов для обучения с собаками
validation_cats_dir = os.path.join(validation_dir, 'cats')  # директория файлов для проверки с кошками
validation_dogs_dir = os.path.join(validation_dir, 'dogs')  # директория файлов для проверки с собаками

# %% [markdown]
# ### Посмотрим на данные

# %%
num_cats_tr = len(os.listdir(train_cats_dir)) # количество файлов для обучения с кошками
num_dogs_tr = len(os.listdir(train_dogs_dir)) # с собаками

num_cats_val = len(os.listdir(validation_cats_dir)) # количество файлов для проверки с кошками
num_dogs_val = len(os.listdir(validation_dogs_dir)) # с собаками

total_train = num_cats_tr + num_dogs_tr # общее число файлов для обучения
total_val = num_cats_val + num_dogs_val # для проверки

# %%
print('total training cat images:', num_cats_tr)
print('total training dog images:', num_dogs_tr)

print('total validation cat images:', num_cats_val)
print('total validation dog images:', num_dogs_val)
print("--")
print("Total training images:", total_train)
print("Total validation images:", total_val)
# Out:
# total training cat images: 1000
# total training dog images: 1000
# total validation cat images: 500
# total validation dog images: 500
# --
# Total training images: 2000
# Total validation images: 1000

# %% [markdown]
# ## Параметры модели

# %%
BATCH_SIZE = 100 # число примеров в пакете
IMG_SHAPE  = 150 # размер изображений (150 на 150 пикселей)

# %% [markdown]
# # Аугментация данных
#
# Вспомогательная функция для рисования

# %%
# функция для рисования
def plotImages(images_arr):
    fig, axes = plt.subplots(1, 5, figsize=(20,20))
    axes = axes.flatten()
    for img, ax in zip(images_arr, axes):
        ax.imshow(img)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Создаем генератор для обучающих данных с аугментациями, вы можете выбрать и другие аугментации\параметры.

# %%
image_gen_train = ImageDataGenerator(
      rescale=1./255, # изменение значения пикселей, это по сути приведет к диапозону 0...1
      rotation_range=40, # повороты
      width_shift_range=0.2, # сдвиги
      height_shift_range=0.2, # сдвиги
      shear_range=0.2, # параллелограмность
      zoom_range=0.2, # масштаб
      horizontal_flip=True, # зеркальные отражения
      fill_mode='nearest') # как заполнять пустые пиксели

# %% [markdown]
# Сейчас наши данные на диске, а не в памяти компьютера. Чтобы генератор брал их с диска используем метод **flow_from_directory** (вместо flow), указываем размер пакета, директорию с данными, перемешивать ли их, размер результирующего изображения, способ задания меток (указаний учителя). Здесь всего два класса (кошки и собаки), поэтому бинарная классификация.

# %%
train_data_gen = image_gen_train.flow_from_directory(batch_size=BATCH_SIZE, # размер пакета
                                                     directory=train_dir, #директория с данными
                                                     shuffle=True, # перемешивать ли
                                                     target_size=(IMG_SHAPE,IMG_SHAPE), # размер результата
                                                     class_mode='binary') # способ задания меток
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# Что возвращает генератор?  Используем генератор в цикле, будет возвращать свое значение для каждой итерации.

# %%
# Что возвращает генератор?
# используем генератор в цикле, будет возвращать свое значение для каждой итерации

tmp = [train_data_gen for i in range(1)]

# %%
tmp1=tmp[0] # итерация 0. Вернулся DirectoryIterator с 20 элементами (2000 примеров \ 100 в пакете), т.е. вернулись все пакеты (эпоха)

# %% [markdown]
# Вернулся DirectoryIterator с 20 элементами (2000 примеров \ 100 в пакете), т.е. вернулись все пакеты (эпоха)

# %%
tmp2=tmp[0][0] # пакет 0. В пакете две составляющие - примеры входов и выходов

# %% [markdown]
# В пакете две составляющие - примеры входов (изображений) и выходов (классов)

# %%
tmp3=tmp[0][0][0] # это все изображения в пакете (100 штук)
tmp4=tmp[0][0][1] # это все метки изображений в пакете (100 штук)

# %%
tmp5=tmp[0][0][0][0] # это изображение 0 из пакета (1 штука)
tmp6=tmp[0][0][1][0] # это метка изображения 0 из пакета (1 штука)

# %% [markdown]
# Посмотрим на некоторые изображения в итерациях.

# %%
augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %% [markdown]
# ### Генератор проверочных данных
# Для проверочных данных, скорей всего, нет смысла делать все-все аугментации, достаточно самых распространенных или вообще без них. Ведь все-таки задача проверки узнать, насколько хороша модель на реальных данных. Здесь мы только приведем значения пикселей к 0...1, поделив их на 255.

# %%
# генератор проверочных данных
image_gen_val = ImageDataGenerator(rescale=1./255)

val_data_gen = image_gen_val.flow_from_directory(batch_size=BATCH_SIZE,
                                                 directory=validation_dir,
                                                 target_size=(IMG_SHAPE, IMG_SHAPE),
                                                 class_mode='binary')
# Out:
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# # Создание модели классификации

# %% [markdown]
# Это будет обычная сеть с четырьмя сверточными слоями, слоями макспулинга.
#
# Добавим и слой Dropout перед полносвязным с вероятностью отброса 0.5.
#
# Полносвязный слой с 512 нейронами и `relu` активацией. Два выхода (по числу классов) с функцией активации `softmax`.
#
# Вы можете модифицировать сеть по своему усмотрению.

# %%
model = tf.keras.models.Sequential([ # сеть из последовательных слоев, перечисляем:
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150, 150, 3)), # сверточный
    tf.keras.layers.MaxPooling2D(2, 2), # пулинг

    tf.keras.layers.Conv2D(64, (3,3), activation='relu'), # сверточный
    tf.keras.layers.MaxPooling2D(2,2), # пулинг

    tf.keras.layers.Conv2D(128, (3,3), activation='relu'), # сверточный
    tf.keras.layers.MaxPooling2D(2,2), # пулинг

    tf.keras.layers.Conv2D(128, (3,3), activation='relu'), # сверточный
    tf.keras.layers.MaxPooling2D(2,2), # пулинг

    tf.keras.layers.Flatten(), # вытягиваем все в вектор

    #tf.keras.layers.Dropout(0.5), # регуляризация дропаут
    tf.keras.layers.Dense(512, activation='relu'), # полносвязный

    tf.keras.layers.Dense(2) # выходной
])

# %% [markdown]
# ### Параметры модели
#
# Используем метод обучения  `adam`. Функция ошибки `sparse_categorical_crossentropy`.
# Наблюдаем за аккуратностью accuracy классификации (метрика).

# %%
model.compile(optimizer='adam', # метод обучения
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), # функция ошибки
              metrics=['accuracy']) # метрика

# %%
model.summary() # информация о модели
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 74, 74, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 36, 36, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 17, 17, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 128)       147584
#
#  max_pooling2d_3 (MaxPoolin  (None, 7, 7, 128)         0
#  g2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 512)               3211776
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 3453634 (13.17 MB)
# Trainable params: 3453634 (13.17 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Обучение модели

# %% [markdown]
# Наши данные теперь создаются генератором, в старых версиях tensorflow нужно использовать метод  `fit_generator` вместо привычного `fit`, в этой не надо.

# %%
# Сохраним необученную модель
model.save_weights('my_model')

# %%
epochs=100 # количество эпох
# обучаем (~15 минут)
history = model.fit(
    train_data_gen, # генератор обучающих данных
    steps_per_epoch=int(np.ceil(total_train / float(BATCH_SIZE))), # количество примеров на одну эпоху
    epochs=epochs, # количество эпох
    validation_data=val_data_gen, # генератор проверочных данных
    validation_steps=int(np.ceil(total_val / float(BATCH_SIZE))) # как часто проводить проверку
)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 23s 753ms/step - loss: 0.7064 - accuracy: 0.5110 - val_loss: 0.6875 - val_accuracy: 0.5010
# Epoch 2/100
# 20/20 [==============================] - 20s 989ms/step - loss: 0.6877 - accuracy: 0.5495 - val_loss: 0.6748 - val_accuracy: 0.5410
# Epoch 3/100
# 20/20 [==============================] - 15s 741ms/step - loss: 0.6709 - accuracy: 0.6000 - val_loss: 0.6248 - val_accuracy: 0.6660
# Epoch 4/100
# 20/20 [==============================] - 15s 770ms/step - loss: 0.6472 - accuracy: 0.6310 - val_loss: 0.6085 - val_accuracy: 0.6730
# Epoch 5/100
# 20/20 [==============================] - 16s 799ms/step - loss: 0.6330 - accuracy: 0.6425 - val_loss: 0.5979 - val_accuracy: 0.6790
# Epoch 6/100
# 20/20 [==============================] - 15s 735ms/step - loss: 0.6286 - accuracy: 0.6410 - val_loss: 0.6047 - val_accuracy: 0.6990
# Epoch 7/100
# 20/20 [==============================] - 14s 722ms/step - loss: 0.6395 - accuracy: 0.6355 - val_loss: 0.6064 - val_accuracy: 0.6650
# Epoch 8/100
# 20/20 [==============================] - 16s 786ms/step - loss: 0.6174 - accuracy: 0.6725 - val_loss: 0.5683 - val_accuracy: 0.7130
# Epoch 9/100
# 20/20 [==============================] - 16s 788ms/step - loss: 0.5901 - accuracy: 0.6875 - val_loss: 0.5931 - val_accuracy: 0.6670
# Epoch 10/100
# 20/20 [==============================] - 16s 791ms/step - loss: 0.5724 - accuracy: 0.7010 - val_loss: 0.5301 - val_accuracy: 0.7270
# Epoch 11/100
# 20/20 [==============================] - 15s 750ms/step - loss: 0.5794 - accuracy: 0.6910 - val_loss: 0.5406 - val_accuracy: 0.7280
# Epoch 12/100
# 20/20 [==============================] - 14s 720ms/step - loss: 0.5751 - accuracy: 0.6835 - val_loss: 0.5142 - val_accuracy: 0.7390
# Epoch 13/100
# 20/20 [==============================] - 14s 725ms/step - loss: 0.5465 - accuracy: 0.7305 - val_loss: 0.5725 - val_accuracy: 0.7130
# Epoch 14/100
# 20/20 [==============================] - 15s 773ms/step - loss: 0.5575 - accuracy: 0.7185 - val_loss: 0.5246 - val_accuracy: 0.7320
# Epoch 15/100
# 20/20 [==============================] - 15s 735ms/step - loss: 0.5582 - accuracy: 0.7130 - val_loss: 0.4900 - val_accuracy: 0.7630
# Epoch 16/100
# 20/20 [==============================] - 16s 789ms/step - loss: 0.5334 - accuracy: 0.7265 - val_loss: 0.5130 - val_accuracy: 0.7480
# Epoch 17/100
# 20/20 [==============================] - 14s 713ms/step - loss: 0
# Epoch 99/100
# 20/20 [==============================] - 14s 717ms/step - loss: 0.2023 - accuracy: 0.9200 - val_loss: 0.4396 - val_accuracy: 0.8250
# Epoch 100/100
# 20/20 [==============================] - 15s 746ms/step - loss: 0.2394 - accuracy: 0.8995 - val_loss: 0.4298 - val_accuracy: 0.8230

# %% [markdown]
# ### Визуализация результатов

# %%
def visualize_my_model(history):
  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']

  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs_range = range(epochs)

  plt.figure(figsize=(8, 8))
  plt.subplot(1, 2, 1)
  plt.plot(epochs_range, acc, label='Training Accuracy')
  plt.plot(epochs_range, val_acc, label='Validation Accuracy')
  plt.legend(loc='lower right')
  plt.title('Training and Validation Accuracy')

  plt.subplot(1, 2, 2)
  plt.plot(epochs_range, loss, label='Training Loss')
  plt.plot(epochs_range, val_loss, label='Validation Loss')
  plt.legend(loc='upper right')
  plt.title('Training and Validation Loss')
  plt.show()

# %%
visualize_my_model(history)

# %% [markdown]
# Получилось довольно не плохо (но, конечно, не идеально) 82% аккуратности на проверке, 88% на обучении.
#
# Сделайте то же самое, но уберите все аугментации (кроме не случайных) и сравните.

# %% [markdown]
# # Классификация кошек и собак без аугментаци данных

# %%
# Без аугментаций
image_gen_train = ImageDataGenerator(
      rescale=1./255, # изменение величины пикселей, это по сути приведет к диапозону 0...1
      fill_mode='nearest') # как заполнять пустые пиксели

# %%
train_data_gen = image_gen_train.flow_from_directory(batch_size=BATCH_SIZE, # размер пакета
                                                     directory=train_dir, #директория с данными
                                                     shuffle=True, # перемешивать ли
                                                     target_size=(IMG_SHAPE,IMG_SHAPE), # размер результата
                                                     class_mode='binary') # способ задания меток
# Out:
# Found 2000 images belonging to 2 classes.

# %%
# Восстановим необученную модель
model.load_weights('my_model')

# %%
epochs=100 # количество эпох
# обучаем (~15 минут)
history = model.fit(
    train_data_gen, # генератор обучающих данных
    steps_per_epoch=int(np.ceil(total_train / float(BATCH_SIZE))), # количество примеров на одну эпоху
    epochs=epochs, # количество эпох
    validation_data=val_data_gen, # генератор проверочных данных
    validation_steps=int(np.ceil(total_val / float(BATCH_SIZE))) # как часто проводить проверку
)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 5s 249ms/step - loss: 0.6964 - accuracy: 0.5055 - val_loss: 0.6869 - val_accuracy: 0.5020
# Epoch 2/100
# 20/20 [==============================] - 6s 287ms/step - loss: 0.6810 - accuracy: 0.5545 - val_loss: 0.6682 - val_accuracy: 0.6150
# Epoch 3/100
# 20/20 [==============================] - 5s 242ms/step - loss: 0.6441 - accuracy: 0.6315 - val_loss: 0.6321 - val_accuracy: 0.6490
# Epoch 4/100
# 20/20 [==============================] - 5s 260ms/step - loss: 0.5965 - accuracy: 0.6770 - val_loss: 0.6965 - val_accuracy: 0.6410
# Epoch 5/100
# 20/20 [==============================] - 5s 237ms/step - loss: 0.5582 - accuracy: 0.7220 - val_loss: 0.5943 - val_accuracy: 0.6770
# Epoch 6/100
# 20/20 [==============================] - 5s 258ms/step - loss: 0.5267 - accuracy: 0.7340 - val_loss: 0.5674 - val_accuracy: 0.7120
# Epoch 7/100
# 20/20 [==============================] - 5s 244ms/step - loss: 0.4854 - accuracy: 0.7585 - val_loss: 0.5772 - val_accuracy: 0.7040
# Epoch 8/100
# 20/20 [==============================] - 6s 291ms/step - loss: 0.4298 - accuracy: 0.8065 - val_loss: 0.5630 - val_accuracy: 0.7260
# Epoch 9/100
# 20/20 [==============================] - 5s 241ms/step - loss: 0.3878 - accuracy: 0.8245 - val_loss: 0.5495 - val_accuracy: 0.7370
# Epoch 10/100
# 20/20 [==============================] - 5s 232ms/step - loss: 0.3771 - accuracy: 0.8240 - val_loss: 0.5713 - val_accuracy: 0.7310
# Epoch 11/100
# 20/20 [==============================] - 5s 255ms/step - loss: 0.3223 - accuracy: 0.8555 - val_loss: 0.6159 - val_accuracy: 0.7410
# Epoch 12/100
# 20/20 [==============================] - 5s 244ms/step - loss: 0.3385 - accuracy: 0.8470 - val_loss: 0.5956 - val_accuracy: 0.7160
# Epoch 13/100
# 20/20 [==============================] - 6s 278ms/step - loss: 0.2804 - accuracy: 0.8875 - val_loss: 0.6481 - val_accuracy: 0.7480
# Epoch 14/100
# 20/20 [==============================] - 5s 255ms/step - loss: 0.2222 - accuracy: 0.9080 - val_loss: 0.6488 - val_accuracy: 0.7440
# Epoch 15/100
# 20/20 [==============================] - 5s 238ms/step - loss: 0.1736 - accuracy: 0.9395 - val_loss: 0.7175 - val_accuracy: 0.7340
# Epoch 16/100
# 20/20 [==============================] - 5s 233ms/step - loss: 0.1263 - accuracy: 0.9545 - val_loss: 0.7714 - val_accuracy: 0.7440
# Epoch 17/100
# 20/20 [==============================] - 6s 277ms/step - loss: 0.0875 - accuracy: 0.9750 - val_loss: 0.8634 - val_accuracy: 0.7530
# Epoch 18/100
# 20/20 [==============================] - 5s 234ms/step - loss: 0.0756 - accuracy: 0.9755 - val_loss: 0.9776 - val_accuracy: 0.7340
# Epoch 19/100
# 20/20 [==============================] - 5s 264ms/step - loss: 0.0884 - accuracy: 0.9720 - val_loss: 1.1091 - val_accuracy: 0.7360
# Epoch 20/100
# 20/20 [==============================] - 5s 233ms/step - loss: 0.1049 - accuracy: 0.9600 - val_loss: 1.0630 - val_accuracy: 0.7240
# Epoch 21/100
# 20/20 [==============================] - 6s 292ms/step - loss: 0.0717 - accuracy: 0.9750 - val_loss: 0.9655 - val_accuracy: 0.7580
# Epoch 22/100
# 20/20 [==============================] - 5s 230ms/step - loss: 0.0290 - accuracy: 0.9945 - val_loss: 1.1391 - val_accuracy: 0.7540
# Epoch 23/100
# 20/20 [==============================] - 6s 292ms/step - loss: 0.0173 - accuracy: 0.9970 - val_loss: 1.3003 - val_accuracy: 0.7510
# Epoch 24/100
# 20/20 [==============================] - 5s 236ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 1.3420 - val_accuracy: 0.7580
# Epoch 25/100
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.3398 - val_accuracy: 0.7550
# Epoch 26/100
# 20/20 [==============================] - 5s 260ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.4238 - val_accuracy: 0.7660
# Epoch 27/100
# 20/20 [==============================] - 5s 242ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.4335 - val_accuracy: 0.7670
# Epoch 28/100
# 20/20 [==============================] - 5s 267ms/step - loss: 9.9371e-04 - accuracy: 1.0000 - val_loss: 1.4777 - val_accuracy: 0.7760
# Epoch 29/100
# 20/20 [==============================] - 5s 245ms/step - loss: 7.1022e-04 - accuracy: 1.0000 - val_loss: 1.5005 - val_accuracy: 0.7700
# Epoch 30/100
# 20/20 [==============================] - 5s 244ms/step - loss: 6.4676e-04 - accuracy: 1.0000 - val_loss: 1.5274 - val_accuracy: 0.7700
# Epoch 31/100
# 20/20 [==============================] - 5s 244ms/step - loss: 5.3151e-04 - accuracy: 1.0000 - val_loss: 1.5521 - val_accuracy: 0.7720
# Epoch 32/100
# 20/20 [==============================] - 5s 235ms/step - loss: 4.7265e-04 - accuracy: 1.0000 - val_loss: 1.5665 - val_accuracy: 0.7680
# Epoch 33/100
# 20/20 [==============================] - 5s 265ms/step - loss: 4.1526e-04 - accuracy: 1.0000 - val_loss: 1.5924 - val_accuracy: 0.7720
# Epoch 34/100
# 20/20 [==============================] - 5s 231ms/step - loss: 3.8628e-04 - accuracy: 1.0000 - val_loss: 1.6121 - val_accuracy: 0.7760
# Epoch 35/100
# 20/20 [==============================] - 5s 262ms/step - loss: 3.5037e-04 - accuracy: 1.0000 - val_loss: 1.6263 - val_accuracy: 0.7720
# Epoch 36/100
# 20/20 [==============================] - 5s 235ms/step - loss: 3.1234e-04 - accuracy: 1.0000 - val_loss: 1.6399 - val_accuracy: 0.7720
# Epoch 37/100
# 20/20 [==============================] - 5s 249ms/step - loss: 2.9090e-04 - accuracy: 1.0000 - val_loss: 1.6577 - val_accuracy: 0.7740
# Epoch 38/100
# 20/20 [==============================] - 5s 239ms/step - loss: 2.6507e-04 - accuracy: 1.0000 - val_loss: 1.6687 - val_accuracy: 0.7720
# Epoch 39/100
# 20/20 [==============================] - 5s 238ms/step - loss: 2.4576e-04 - accuracy: 1.0000 - val_loss: 1.6872 - val_accuracy: 0.7730
# Epoch 40/100
# 20/20 [==============================] - 5s 261ms/step - loss: 2.2723e-04 - accuracy: 1.0000 - val_loss: 1.6985 - val_accuracy: 0.7750
# Epoch 41/100
# 20/20 [==============================] - 5s 237ms/step - loss: 2.1091e-04 - accuracy: 1.0000 - val_loss: 1.7084 - val_accuracy: 0.7720
# Epoch 42/100
# 20/20 [==============================] - 5s 255ms/step - loss: 1.9705e-04 - accuracy: 1.0000 - val_loss: 1.7238 - val_accuracy: 0.7740
# Epoch 43/100
# 20/20 [==============================] - 5s 242ms/step - loss: 1.8442e-04 - accuracy: 1.0000 - val_loss: 1.7360 - val_accuracy: 0.7730
# Epoch 44/100
# 20/20 [==============================] - 5s 237ms/step - loss: 1.7318e-04 - accuracy: 1.0000 - val_loss: 1.7468 - val_accuracy: 0.7720
# Epoch 45/100
# 20/20 [==============================] - 5s 252ms/step - loss: 1.6255e-04 - accuracy: 1.0000 - val_loss: 1.7573 - val_accuracy: 0.7720
# Epoch 46/100
# 20/20 [==============================] - 6s 286ms/step - loss: 1.5508e-04 - accuracy: 1.0000 - val_loss: 1.7704 - val_accuracy: 0.7730
# Epoch 47/100
# 20/20 [==============================] - 5s 269ms/step - loss: 1.4359e-04 - accuracy: 1.0000 - val_loss: 1.7756 - val_accuracy: 0.7710
# Epoch 48/100
# 20/20 [==============================] - 5s 234ms/step - loss: 1.3592e-04 - accuracy: 1.0000 - val_loss: 1.7882 - val_accuracy: 0.7720
# Epoch 49/100
# 20/20 [==============================] - 5s 266ms/step - loss: 1.2878e-04 - accuracy: 1.0000 - val_loss: 1.7994 - val_accuracy: 0.7730
# Epoch 50/100
# 20/20 [==============================] - 5s 230ms/step - loss: 1.2198e-04 - accuracy: 1.0000 - val_loss: 1.8070 - val_accuracy: 0.7730
# Epoch 51/100
# 20/20 [==============================] - 5s 254ms/step - loss: 1.1544e-04 - accuracy: 1.0000 - val_loss: 1.8156 - val_accuracy: 0.7730
# Epoch 52/100
# 20/20 [==============================] - 5s 235ms/step - loss: 1.1102e-04 - accuracy: 1.0000 - val_loss: 1.8249 - val_accuracy: 0.7710
# Epoch 53/100
# 20/20 [==============================] - 5s 235ms/step - loss: 1.0598e-04 - accuracy: 1.0000 - val_loss: 1.8333 - val_accuracy: 0.7740
# Epoch 54/100
# 20/20 [==============================] - 5s 256ms/step - loss: 9.9705e-05 - accuracy: 1.0000 - val_loss: 1.8430 - val_accuracy: 0.7740
# Epoch 55/100
# 20/20 [==============================] - 5s 263ms/step - loss: 9.5215e-05 - accuracy: 1.0000 - val_loss: 1.8504 - val_accuracy: 0.7720
# Epoch 56/100
# 20/20 [==============================] - 5s 233ms/step - loss: 9.0830e-05 - accuracy: 1.0000 - val_loss: 1.8589 - val_accuracy: 0.7730
# Epoch 57/100
# 20/20 [==============================] - 6s 294ms/step - loss: 8.6478e-05 - accuracy: 1.0000 - val_loss: 1.8654 - val_accuracy: 0.7720
# Epoch 58/100
# 20/20 [==============================] - 5s 232ms/step - loss: 8.3510e-05 - accuracy: 1.0000 - val_loss: 1.8746 - val_accuracy: 0.7720
# Epoch 59/100
# 20/20 [==============================] - 5s 244ms/step - loss: 7.9290e-05 - accuracy: 1.0000 - val_loss: 1.8804 - val_accuracy: 0.7740
# Epoch 60/100
# 20/20 [==============================] - 5s 251ms/step - loss: 7.6177e-05 - accuracy: 1.0000 - val_loss: 1.8882 - val_accuracy: 0.7750
# Epoch 61/100
# 20/20 [==============================] - 5s 244ms/step - loss: 7.2590e-05 - accuracy: 1.0000 - val_loss: 1.8973 - val_accuracy: 0.7730
# Epoch 62/100
# 20/20 [==============================] - 5s 256ms/step - loss: 6.9927e-05 - accuracy: 1.0000 - val_loss: 1.9038 - val_accuracy: 0.7750
# Epoch 63/100
# 20/20 [==============================] - 5s 237ms/step - loss: 6.6992e-05 - accuracy: 1.0000 - val_loss: 1.9114 - val_accuracy: 0.7740
# Epoch 64/100
# 20/20 [==============================] - 5s 259ms/step - loss: 6.4460e-05 - accuracy: 1.0000 - val_loss: 1.9171 - val_accuracy: 0.7750
# Epoch 65/100
# 20/20 [==============================] - 5s 239ms/step - loss: 6.1898e-05 - accuracy: 1.0000 - val_loss: 1.9237 - val_accuracy: 0.7750
# Epoch 66/100
# 20/20 [==============================] - 5s 235ms/step - loss: 5.9679e-05 - accuracy: 1.0000 - val_loss: 1.9302 - val_accuracy: 0.7750
# Epoch 67/100
# 20/20 [==============================] - 5s 270ms/step - loss: 5.7276e-05 - accuracy: 1.0000 - val_loss: 1.9378 - val_accuracy: 0.7760
# Epoch 68/100
# 20/20 [==============================] - 5s 235ms/step - loss: 5.5770e-05 - accuracy: 1.0000 - val_loss: 1.9456 - val_accuracy: 0.7750
# Epoch 69/100
# 20/20 [==============================] - 5s 263ms/step - loss: 5.3722e-05 - accuracy: 1.0000 - val_loss: 1.9496 - val_accuracy: 0.7750
# Epoch 70/100
# 20/20 [==============================] - 5s 234ms/step - loss: 5.1151e-05 - accuracy: 1.0000 - val_loss: 1.9572 - val_accuracy: 0.7760
# Epoch 71/100
# 20/20 [==============================] - 6s 292ms/step - loss: 4.9709e-05 - accuracy: 1.0000 - val_loss: 1.9620 - val_accuracy: 0.7750
# Epoch 72/100
# 20/20 [==============================] - 5s 238ms/step - loss: 4.7892e-05 - accuracy: 1.0000 - val_loss: 1.9683 - val_accuracy: 0.7760
# Epoch 73/100
# 20/20 [==============================] - 6s 296ms/step - loss: 4.6230e-05 - accuracy: 1.0000 - val_loss: 1.9741 - val_accuracy: 0.7750
# Epoch 74/100
# 20/20 [==============================] - 5s 229ms/step - loss: 4.4757e-05 - accuracy: 1.0000 - val_loss: 1.9792 - val_accuracy: 0.7750
# Epoch 75/100
# 20/20 [==============================] - 5s 238ms/step - loss: 4.3318e-05 - accuracy: 1.0000 - val_loss: 1.9862 - val_accuracy: 0.7750
# Epoch 76/100
# 20/20 [==============================] - 5s 259ms/step - loss: 4.1709e-05 - accuracy: 1.0000 - val_loss: 1.9920 - val_accuracy: 0.7750
# Epoch 77/100
# 20/20 [==============================] - 5s 239ms/step - loss: 4.0366e-05 - accuracy: 1.0000 - val_loss: 1.9969 - val_accuracy: 0.7760
# Epoch 78/100
# 20/20 [==============================] - 5s 257ms/step - loss: 3.9002e-05 - accuracy: 1.0000 - val_loss: 2.0034 - val_accuracy: 0.7750
# Epoch 79/100
# 20/20 [==============================] - 5s 262ms/step - loss: 3.7833e-05 - accuracy: 1.0000 - val_loss: 2.0076 - val_accuracy: 0.7760
# Epoch 80/100
# 20/20 [==============================] - 5s 237ms/step - loss: 3.6668e-05 - accuracy: 1.0000 - val_loss: 2.0131 - val_accuracy: 0.7750
# Epoch 81/100
# 20/20 [==============================] - 6s 293ms/step - loss: 3.5373e-05 - accuracy: 1.0000 - val_loss: 2.0185 - val_accuracy: 0.7750
# Epoch 82/100
# 20/20 [==============================] - 5s 234ms/step - loss: 3.4364e-05 - accuracy: 1.0000 - val_loss: 2.0238 - val_accuracy: 0.7760
# Epoch 83/100
# 20/20 [==============================] - 5s 264ms/step - loss: 3.3339e-05 - accuracy: 1.0000 - val_loss: 2.0296 - val_accuracy: 0.7760
# Epoch 84/100
# 20/20 [==============================] - 5s 232ms/step - loss: 3.2455e-05 - accuracy: 1.0000 - val_loss: 2.0324 - val_accuracy: 0.7750
# Epoch 85/100
# 20/20 [==============================] - 5s 260ms/step - loss: 3.1520e-05 - accuracy: 1.0000 - val_loss: 2.0383 - val_accuracy: 0.7760
# Epoch 86/100
# 20/20 [==============================] - 5s 229ms/step - loss: 3.0451e-05 - accuracy: 1.0000 - val_loss: 2.0424 - val_accuracy: 0.7770
# Epoch 87/100
# 20/20 [==============================] - 6s 295ms/step - loss: 2.9572e-05 - accuracy: 1.0000 - val_loss: 2.0484 - val_accuracy: 0.7770
# Epoch 88/100
# 20/20 [==============================] - 5s 235ms/step - loss: 2.8720e-05 - accuracy: 1.0000 - val_loss: 2.0528 - val_accuracy: 0.7770
# Epoch 89/100
# 20/20 [==============================] - 5s 235ms/step - loss: 2.8070e-05 - accuracy: 1.0000 - val_loss: 2.0590 - val_accuracy: 0.7750
# Epoch 90/100
# 20/20 [==============================] - 5s 261ms/step - loss: 2.7037e-05 - accuracy: 1.0000 - val_loss: 2.0628 - val_accuracy: 0.7780
# Epoch 91/100
# 20/20 [==============================] - 5s 239ms/step - loss: 2.6293e-05 - accuracy: 1.0000 - val_loss: 2.0674 - val_accuracy: 0.7760
# Epoch 92/100
# 20/20 [==============================] - 5s 265ms/step - loss: 2.5530e-05 - accuracy: 1.0000 - val_loss: 2.0717 - val_accuracy: 0.7760
# Epoch 93/100
# 20/20 [==============================] - 5s 233ms/step - loss: 2.4876e-05 - accuracy: 1.0000 - val_loss: 2.0762 - val_accuracy: 0.7760
# Epoch 94/100
# 20/20 [==============================] - 6s 293ms/step - loss: 2.4299e-05 - accuracy: 1.0000 - val_loss: 2.0821 - val_accuracy: 0.7760
# Epoch 95/100
# 20/20 [==============================] - 6s 290ms/step - loss: 2.3560e-05 - accuracy: 1.0000 - val_loss: 2.0845 - val_accuracy: 0.7760
# Epoch 96/100
# 20/20 [==============================] - 6s 293ms/step - loss: 2.3002e-05 - accuracy: 1.0000 - val_loss: 2.0905 - val_accuracy: 0.7760
# Epoch 97/100
# 20/20 [==============================] - 5s 233ms/step - loss: 2.2372e-05 - accuracy: 1.0000 - val_loss: 2.0930 - val_accuracy: 0.7770
# Epoch 98/100
# 20/20 [==============================] - 5s 239ms/step - loss: 2.1925e-05 - accuracy: 1.0000 - val_loss: 2.0988 - val_accuracy: 0.7760
# Epoch 99/100
# 20/20 [==============================] - 5s 256ms/step - loss: 2.1303e-05 - accuracy: 1.0000 - val_loss: 2.1041 - val_accuracy: 0.7770
# Epoch 100/100
# 20/20 [==============================] - 5s 247ms/step - loss: 2.0719e-05 - accuracy: 1.0000 - val_loss: 2.1076 - val_accuracy: 0.7760

# %%
# Смотрим на результат
visualize_my_model(history)

# %% [markdown]
# У меня получилось 77% аккуратности на проверке (еще и возрастает), 99% на обучении! Явно проблема сильного  переобучения.  Но зато обучение было в три раза быстрее.
#
# Итак, аугментация приносит пользу в борьбе с переобучением.

# %% [markdown]
# # Ссылки
#
# Использованы и адаптированы материалы
#
# https://colab.research.google.com/github/dufourpascal/stepupai/blob/master/tutorials/data_augmentation/exploring_data_augmentation_keras.ipynb#scrollTo=2KpA-QvpPCqi
#
# https://colab.research.google.com/github/tensorflow/examples/blob/master/courses/udacity_intro_to_tensorflow_for_deep_learning/l05c02_dogs_vs_cats_with_augmentation.ipynb#scrollTo=tGNKLa_YVrXR
#
# https://colab.research.google.com/github/dufourpascal/stepupai/blob/master/tutorials/data_augmentation/custom_data_augmentation_keras.ipynb
